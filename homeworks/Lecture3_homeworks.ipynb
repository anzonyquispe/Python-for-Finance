# %% [markdown]
# ## Lecture 3 — If / Loops / Functions / Classes
#
# Using the same kind of objects as in the lecture notebook (tickers like **SPY, AAPL, MSFT, JPM, NVDA**), build:
#
# - an **IF-based classification block**
# - **loop-based metrics**
# - a small **OOP structure** (`MacroSeries`) + **validations** using custom **exceptions**

# %% [markdown]
# 1. Create the ticker list `(SPY, AAPL, MSFT, JPM, NVDA)` and loop over it with a `for`, printing **index and value**.

# %% [markdown]
# 2. Write an `if/elif/else` that classifies a number as **negative / zero / positive**.

# %% [markdown]
# 3. Build a list of **last prices** (you may simulate them if you don’t download) and compute the **median**.

# %% [markdown]
# 4. Using a loop, label each ticker as `HIGH_PRICE` if its last price > median; otherwise label it `LOW_PRICE`.

# %% [markdown]
# 5. Repeat the logic but handle `NaN`: if the value is missing, label it `UNKNOWN`.

# %% [markdown]
# 6. Create a dictionary `{ticker: last_close}` and iterate over `.items()` to produce a **sorted report**.

# %% [markdown]
# 7. Use `range()` to iterate in windows (e.g., from 0 to n-1) and display **consecutive pairs** of tickers.

# %% [markdown]
# 8. Use a nested `for` loop to generate all **unique ticker–ticker combinations** (no repeats) and count how many there are.

# %% [markdown]
# 9. Write a function `safe_float(x)` that returns `NaN` if conversion fails.

# %% [markdown]
# 10. Add `try/except` so the pipeline does not crash when a value is invalid.

# %% [markdown]
# 11. Define a class `MacroSeries(name, source, data)` (as in the notebook) and validate that `data` is a **DataFrame**.

# %% [markdown]
# 12. In `__init__`, validate that columns `date` and `value` exist (raise an error if missing).

# %% [markdown]
# 13. Add a `.summary()` method returning: `min`, `max`, `mean`, and `n` observations.

# %% [markdown]
# 14. Create a base exception `FinanceDataError` and two subclasses: `DataDownloadError`, `DataValidationError`.

# %% [markdown]
# 15. Implement `require_nonempty(df, label)` and test that it raises `DataDownloadError` when `df` is empty.

# %% [markdown]
# 16. Implement `require_column(df, col, label)` and test that it raises `DataValidationError` when a required column is missing.

# %% [markdown]
# 17. Show a simple **inheritance example** (a child class that extends/overrides a method).

# %% [markdown]
# 18. Create a “private variable” (e.g., `_cache_key`) and explain how you would use it for caching.

# %% [markdown]
# 19. Build a mini “pipeline” that: **validate → classify tickers → returns a final table**.

# %% [markdown]
# 20. Simulate a failure case (empty df or missing columns) and show the error is **clear and controlled**.
