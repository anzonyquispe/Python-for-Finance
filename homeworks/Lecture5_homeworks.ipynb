# %% [markdown]
# ## Lecture 5 — Full Pipeline + ECDF/FOSD/SOSD + Portfolios + Backtest
# Reproduce the main notebook workflow using:
#
# - **Yahoo tickers**: `EPU`, `IWM`, `IEF`, `VNQ`, `HYG`
# - **BCRP monthly series**: `PD04722MM`, `PD31895MM`, `PN01129XM`, `PN01246PM`
#
# **Deliverables**
# - Final **monthly dataset** (merged + exported)
# - **Distribution plots** (histograms + ECDF)
# - **FOSD/SOSD analysis** + simple bootstrap
# - Portfolio optimization (**min-variance**, **max-Sharpe**), **efficient frontier**, and **expanding-window backtest**

# %% [markdown]
# 1. Define pipeline parameters (dates, tickers, Peru codes) exactly as in the notebook.

# %% [markdown]
# 2. Use the API helper to download **daily Yahoo prices** and keep the dataset in **long format**.

# %% [markdown]
# 3. Inspect the data: `head/tail`, counts per ticker, NA per ticker, and date ranges.

# %% [markdown]
# 4. Compute **daily returns** per ticker and validate: no `inf`, no duplicate dates.

# %% [markdown]
# 5. Convert to **monthly compounded returns** per ticker and explain the formula.

# %% [markdown]
# 6. Compute **weekly returns** and compare weekly vs monthly in terms of mean/volatility.

# %% [markdown]
# 7. Create **monthly summary stats** per ticker (mean, sd, skewness or percentiles).

# %% [markdown]
# 8. Make distribution plots: **histogram per asset** (monthly returns).

# %% [markdown]
# 9. Implement `ECDF(x)` (as in the exercise) and test it on one asset.

# %% [markdown]
# 10. Plot ECDFs for all assets on the same chart and provide **two observations**.

# %% [markdown]
# 11. Implement an approximate **FOSD** test on a grid for two assets and conclude.

# %% [markdown]
# 12. Implement an approximate **SOSD** test for the same pair and conclude.

# %% [markdown]
# 13. Run a simple **bootstrap** for an SOSD gap (as in the notebook exercise).

# %% [markdown]
# 14. Download **BCRP monthly series** (`PD04722MM`, `PD31895MM`, `PN01129XM`, `PN01246PM`) and reshape to **wide**.

# %% [markdown]
# 15. Monthly merge: combine **asset monthly returns** + **BCRP monthly data**, then export to CSV.

# %% [markdown]
# 16. Implement portfolio functions: expected return and variance (given `w`, `mu`, `Sigma`).

# %% [markdown]
# 17. Solve **minimum variance** using SLSQP (`sum(w)=1`, `w>=0`) and report weights.

# %% [markdown]
# 18. Solve **maximum Sharpe** using `PD04722MM` as a proxy for `rf` (frequency-consistent) and report weights.

# %% [markdown]
# 19. Construct and plot the **efficient frontier** (target returns) and mark the **min-var** and **max-Sharpe** portfolios.

# %% [markdown]
# 20. Run an **expanding-window backtest** (e.g., 36-month training window) comparing **max-Sharpe vs equal-weight**, and summarize performance.
